# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Importing necessary libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os
from sklearn.model_selection import train_test_split
#from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from keras.models import Sequential

# %%
data = []
labels = []
classes = 4
cur_path = '/content/gdrive/MyDrive/Sunik_sample_data/data'

# %%
cur_path
# Out:
# '/content/gdrive/MyDrive/Sunik_sample_data/data'

# %%
for i in range(classes):
    path = os.path.join(cur_path,'train',str(i))
    print(path)
# Out:
# /content/gdrive/MyDrive/Sunik_sample_data/data/train/0
# /content/gdrive/MyDrive/Sunik_sample_data/data/train/1
# /content/gdrive/MyDrive/Sunik_sample_data/data/train/2
# /content/gdrive/MyDrive/Sunik_sample_data/data/train/3

# %%
#Retrieving the images and their labels 
for i in range(classes):
    path = os.path.join(cur_path,'train',str(i))
    images = os.listdir('/content/gdrive/MyDrive/Sunik_sample_data/data/train')
    print(images)
# Out:
# ['1', '2', '3', '0', '.ipynb_checkpoints']
# ['1', '2', '3', '0', '.ipynb_checkpoints']
# ['1', '2', '3', '0', '.ipynb_checkpoints']
# ['1', '2', '3', '0', '.ipynb_checkpoints']

# %%
#Retrieving the images and their labels 
for i in range(classes):
    path = os.path.join(cur_path,'train',str(i))
    images = os.listdir(path)
    #print(images)

    for a in images:
        try:
            image = Image.open(path + '\\'+ a)
            image = image.resize((30,30))
            image = np.array(image)
            sim = Image.fromarray(image)
            data.append(image)
            labels.append(i)
        except:
            print("Error loading image")
# Out:
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# ...

# %%
data = np.array(data)
labels = np.array(labels)

# %%
print(data)
# Out:
# []

# %%
data = []
labels = []
classes = 4
cur_path = os.getcwd()

# %%
#import os
#print(os.listdir('/content/gdrive/MyDrive/Sunik_sample_data/data/train/1'))

# %%
#Retrieving the images and their labels 
for i in range(classes):
    path = os.path.join('/content/gdrive/MyDrive/Sunik_sample_data/data/train','train',str(i))
    images = os.listdir('/content/gdrive/MyDrive/Sunik_sample_data/data/train')
    #print(path)
    for a in images:
        try:
            image = Image.open(path + '\\'+ a)
            image = image.resize((30,30))
            image = np.array(image)
            #sim = Image.fromarray(image)
            data.append(image)
            labels.append(i)
        except:
            print("Error loading image")
# Out:
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image
# Error loading image

# %%
for a in images:
  try:
      image = images.open('/content/gdrive/MyDrive/Sunik_sample_data/Cyclone_Images'+ '\\'+ a)
      image = image.resize((30,30))
      image = np.array(image)
#sim = Image.fromarray(image)
      data.append(image)
      labels.append(i)
  except:
      print("Error loading image")
# Out:
# Error loading image
# Error loading image
# Error loading image
# Error loading image

# %%
#Converting lists into numpy arrays
data = np.array(data)
labels = np.array(labels)

print(data.shape, labels.shape)
